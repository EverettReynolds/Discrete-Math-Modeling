# %%
3+3
# Out:
# 6

# %%
4+4
# Out:
# 8

# %%
4+4
# Out:
# 8

# %%
print("My Mom")
# Out:
# My Mom

# %%
dookie = 42;
duke = 0;
dookie + dookie = duke;
# Out:
#   File "/tmp/ipykernel_609/3133903510.py", line 3
#     dookie + dookie = duke;
#     ^
# SyntaxError: cannot assign to operator

# %%
duke = dookie + dookie;
print(duke);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_609/3435305595.py in <module>
# ----> 1 duke = dookie + dookie;
#       2 print(duke);
#
# NameError: name 'dookie' is not defined

# %%
dookie = 42;
duke = 0;
duke = dookie + dookie;

# %%
dookie = 42;
duke = 0;
duke = dookie + dookie;
print("duke");
# Out:
# duke

# %%
dookie = 42;
duke = 0;
duke = dookie + dookie;
print(duke);
# Out:
# 84

# %%
print('f')
# Out:
# f

# %%
print("f")
# Out:
# f

# %%
print('fr')
# Out:
# fr

# %%
#first program
print("Hello, World")
name = "Jane Doe"
print("Hello, " + name)
# Out:
# Hello, World
# Hello, Jane Doe

# %%
a = [1,2,3,4]
a[0]
# Out:
# 1

# %%
a[2]
# Out:
# 3

# %%
a,b = 3.14159265, "miracle"
a
b
# Out:
# 'miracle'

# %%
a
# Out:
# 3.14159265

# %%
b
# Out:
# 'miracle'

# %%
for i in ['a','b','c']:
    print ("The Letter Is: ")
    print(i)
print ("The End!")
# Out:
# The Letter Is:
# a
# The Letter Is:
# b
# The Letter Is:
# c
# The End!

# %%
for i in ['Nuts','Beans','Garden Instruments']:
    print ("Deez ")
    print(i)
print ("Wow.")
# Out:
# Deez
# Nuts
# Deez
# Beans
# Deez
# Garden Instruments
# Wow.

# %%
for i in ['a','b','c']:
    print ("The Letter Is: ")
    print(i)
print ("The End!")
# Out:
# The Letter Is:
# a
# The Letter Is:
# b
# The Letter Is:
# c
# The End!

# %%
for i in range(0,3):
    print(2**i)
# Out:
# 1
# 2
# 4

# %%
32**7
# Out:
# 34359738368

# %%
for i in range(0,50):
    print(2**i)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576
# 2097152
# 4194304
# 8388608
# 16777216
# 33554432
# 67108864
# 134217728
# 268435456
# 536870912
# 1073741824
# 2147483648
# 4294967296
# 8589934592
# 17179869184
# 34359738368
# 68719476736
# 137438953472
# 274877906944
# 549755813888
# 1099511627776
# 2199023255552
# 4398046511104
# 8796093022208
# 17592186044416
# 35184372088832
# 70368744177664
# 140737488355328
# 281474976710656
# 562949953421312

# %%
for i in range(0,100):
    print(2**i)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576
# 2097152
# 4194304
# 8388608
# 16777216
# 33554432
# 67108864
# 134217728
# 268435456
# 536870912
# 1073741824
# 2147483648
# 4294967296
# 8589934592
# 17179869184
# 34359738368
# 68719476736
# 137438953472
# 274877906944
# 549755813888
# 1099511627776
# 2199023255552
# 4398046511104
# 8796093022208
# 17592186044416
# 35184372088832
# 70368744177664
# 140737488355328
# 281474976710656
# 562949953421312
# 1125899906842624
# 2251799813685248
# 4503599627370496
# 9007199254740992
# 18014398509481984
# 36028797018963968
# 72057594037927936
# 144115188075855872
# 288230376151711744
# 576460752303423488
# 1152921504606846976
# 2305843009213693952
# 4611686018427387904
# 9223372036854775808
# 18446744073709551616
# 36893488147419103232
# 73786976294838206464
# 147573952589676412928
# 295147905179352825856
# 590295810358705651712
# 1180591620717411303424
# ...

# %%
for i in range(0,200):
    print(20**i)
# Out:
# 1
# 20
# 400
# 8000
# 160000
# 3200000
# 64000000
# 1280000000
# 25600000000
# 512000000000
# 10240000000000
# 204800000000000
# 4096000000000000
# 81920000000000000
# 1638400000000000000
# 32768000000000000000
# 655360000000000000000
# 13107200000000000000000
# 262144000000000000000000
# 5242880000000000000000000
# 104857600000000000000000000
# 2097152000000000000000000000
# 41943040000000000000000000000
# 838860800000000000000000000000
# 16777216000000000000000000000000
# 335544320000000000000000000000000
# 6710886400000000000000000000000000
# 134217728000000000000000000000000000
# 2684354560000000000000000000000000000
# 53687091200000000000000000000000000000
# 1073741824000000000000000000000000000000
# 21474836480000000000000000000000000000000
# 429496729600000000000000000000000000000000
# 8589934592000000000000000000000000000000000
# 171798691840000000000000000000000000000000000
# 3435973836800000000000000000000000000000000000
# 68719476736000000000000000000000000000000000000
# ...

# %%
for i in range(0,3):
    print(200**i)
# Out:
# 1
# 200
# 40000

# %%
for i in range(0,500):
    print(2**i)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576
# 2097152
# 4194304
# 8388608
# 16777216
# 33554432
# 67108864
# 134217728
# 268435456
# 536870912
# 1073741824
# 2147483648
# 4294967296
# 8589934592
# 17179869184
# 34359738368
# 68719476736
# 137438953472
# 274877906944
# 549755813888
# 1099511627776
# 2199023255552
# 4398046511104
# 8796093022208
# 17592186044416
# 35184372088832
# 70368744177664
# 140737488355328
# 281474976710656
# 562949953421312
# 1125899906842624
# 2251799813685248
# 4503599627370496
# 9007199254740992
# 18014398509481984
# 36028797018963968
# 72057594037927936
# 144115188075855872
# 288230376151711744
# 576460752303423488
# 1152921504606846976
# 2305843009213693952
# 4611686018427387904
# 9223372036854775808
# 18446744073709551616
# 36893488147419103232
# 73786976294838206464
# 147573952589676412928
# 295147905179352825856
# 590295810358705651712
# 1180591620717411303424
# ...

# %%
for i in range(0,10000):
    print(4567**i)
# Out:
# WARNING: Some output was deleted.

# %%
for i in range(0,10):
    print(3*i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27

# %%
for i in range(1,10):
    print(3*i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27

# %%
for i in range(1,11):
    print(3*i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
for i in range(0,99):
    sum = 0
    print(sum+=i)
# Out:
#   File "/tmp/ipykernel_609/2643337929.py", line 3
#     print(sum+=i)
#              ^
# SyntaxError: invalid syntax

# %%
sum = 0
for i in range(0,99):
    sum+=i
    print(sum)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851

# %%
sum = 0
for i in range(1,101):
    sum+=i
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 5050

# %%
sum = 0
for i in range(0,99):
    sum+=i
print(sum)
# Out:
# 4851

# %%
sum = 0
for i in range(1,101):
    sum+=i
print(sum)
# Out:
# 5050
